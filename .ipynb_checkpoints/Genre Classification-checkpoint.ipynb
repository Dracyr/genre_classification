# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Genre Classification
#
# Data available on https://drive.google.com/drive/folders/1gxVDm5CsnzQu7MzzyH8Mx3mQiy877oks?usp=sharing
#
# If you are on python3 you can get by on `audio_data.pkl` but the raw files are included for completeness

# %% [markdown]
# Read the files and sort them so that the labels and data will be in the same order for later training

# %%
# Change to file location
dataset_path = "/Users/pepe/Documents/Music Datasets/"

audio_files = []
for file in os.listdir(dataset_path + "audio/"):
    if file.endswith(".mp3"):
        audio_files.append(os.path.join(dataset_path + "audio/", file))
audio_files.sort()        

annotation_files = []
for file in os.listdir(dataset_path + "annotations/genre/"):
    if file.endswith(".genre"):
        annotation_files.append(os.path.join(dataset_path + "annotations/genre/", file))
annotation_files.sort()

# %% [markdown]
# Encode the text labels to numbers
#
# For more info, read http://scikit-learn.org/stable/modules/preprocessing_targets.html#label-encoding

# %%
from sklearn import preprocessing

annotations = []
for file in annotation_files:
    f = open(file)
    genre = f.read().strip()
    annotations.append(genre)

#le = 
ann = preprocessing.LabelEncoder().fit_transform(annotations)

# %% [markdown]
# We now want to generate the spectrograms, we use mel-spectrograms here since they compress the data well and match how human hearing works

# %%
import librosa

def file_to_spectrogram(path, seconds=30):
    y, sr = librosa.load(path)
    # Cut the audio to the first 30 seconds
    y = y[:seconds * sr] 
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128,fmax=8000)
    return S

# %% [markdown]
# Plot the spectrogram for the first audio file in the dataset

# %%
import matplotlib.pyplot as plt
import librosa.display

def plot_spectrogram(spectrogram):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(librosa.power_to_db(spectrogram, ref=np.max), y_axis='mel', fmax=8000, x_axis='time')
    
    plt.colorbar(format='%+2.0f dB')
    plt.title('Mel spectrogram')
    plt.tight_layout()
    plt.show()

first_file = file_to_spectrogram(audio_files[0])
plot_spectrogram(first_file)

# %% [markdown]
# Now we generate spectrograms for all of the files, this takes some time to do so if you have python3 prefer to read from the pickled file

# %%
from sklearn.externals import joblib

# Change this variable to generate spectrograms for fewer tracks
generate_count = len(audio_files)

# Change this variable to true to actually generate the data, else we try to read from the pkl file
generate_data = False
if generate_data:
    i = 0
    d = []
    for file in audio_files[:generate_count]:
        i = i + 1
        print("\r" + str(i) + "/" + str(len(audio_files)), end='')
        d.append(file_to_spectrogram(file))   
    audio_data = np.stack(d, axis=0)
    # Persist data to disk
    joblib.dump(audio_data, 'audio_data.pkl')
# Out:
# 664/664

# %%
audio_data = joblib.load('audio_data.pkl') 

print(audio_data.shape)
# Out:
# (664, 128, 1292)

# %%
from sklearn.model_selection import train_test_split

# %%
# We cut the data to match how many we generated
X = audio_data
y = ann[:len(X)]

# Resample for the sklearn models sake
nsamples, nx, ny = X.shape
X2 = X.reshape((nsamples,nx*ny))

X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.20, random_state=42)

# %%
# This really braindead classifier is not going to work well, but it is going to make predictions
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_pred)
# Out:
# 0.16541353383458646

# %% [markdown]
# So that accuracy is kind of bad, can you improve it? :)

# %%
import torch 
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable

# %%
# Hyper Parameters
num_epochs = 5
batch_size = 100
learning_rate = 0.001

print("asd322")
# MNIST Dataset
train_dataset = dsets.MNIST(root='./data/',
                            train=True, 
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root='./data/',
                           train=False, 
                           transform=transforms.ToTensor())

# Data Loader (Input Pipeline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

print("hej")
# CNN Model (2 conv layer)
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=5, padding=2),
            nn.BatchNorm2d(16),
            nn.ReLU(),
            nn.MaxPool2d(2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=5, padding=2),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2))
        self.fc = nn.Linear(7*7*32, 10)
        
    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out
        
cnn = CNN()
print("CNN laddad")

# Loss and Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(cnn.parameters(), lr=learning_rate)

# Train the Model
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = Variable(images)
        labels = Variable(labels)
        
        # Forward + Backward + Optimize
        optimizer.zero_grad()
        outputs = cnn(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print ('Epoch [%d/%d], Iter [%d/%d] Loss: %.4f' 
                   %(epoch+1, num_epochs, i+1, len(train_dataset)//batch_size, loss.data[0]))

# Test the Model
cnn.eval()  # Change model to 'eval' mode (BN uses moving mean/var).
correct = 0
total = 0
for images, labels in test_loader:
    images = Variable(images)
    outputs = cnn(images)
    _, predicted = torch.max(outputs.data, 1)
    total += labels.size(0)
    correct += (predicted == labels).sum()

print('Test Accuracy of the model on the 10000 test images: %d %%' % (100 * correct / total))

# Save the Trained Model
torch.save(cnn.state_dict(), 'cnn.pkl')
